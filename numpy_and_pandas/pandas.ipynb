# %%
import pandas as pd

subway_df = pd.read_csv('nyc_subway_weather.csv')

data = subway_df.groupby('day_week').mean()['ENTRIESn_hourly']
data
# Out:
# day_week
# 0    1825.264907
# 1    2164.836433
# 2    2297.097957
# 3    2317.072379
# 4    2277.372294
# 5    1383.901479
# 6    1066.436106
# Name: ENTRIESn_hourly, dtype: float64

# %%
# %pylab inline
import seaborn as sns
data.plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
subway_df.groupby('day_week').sum()['ENTRIESn_hourly']
# Out:
#        UNIT     DATEn     TIMEn  ENTRIESn   EXITSn  ENTRIESn_hourly  \
# 0      R003  05-01-11  00:00:00   4388333  2911002              0.0
# 1      R003  05-01-11  04:00:00   4388333  2911002              0.0
# 2      R003  05-01-11  12:00:00   4388333  2911002              0.0
# 3      R003  05-01-11  16:00:00   4388333  2911002              0.0
# 4      R003  05-01-11  20:00:00   4388333  2911002              0.0
# 5      R003  05-02-11  00:00:00   4388348  2911036             15.0
# 6      R003  05-02-11  04:00:00   5818689  3874767             19.0
# 7      R003  05-02-11  08:00:00   4388855  2911194            488.0
# 8      R003  05-02-11  12:00:00   4389345  2911326            490.0
# 9      R003  05-02-11  16:00:00   4389576  2911558            231.0
# 10     R003  05-02-11  20:00:00   4389811  2911963            235.0
# 11     R003  05-03-11  00:00:00   4389885  2912127             74.0
# 12     R003  05-03-11  04:00:00   4389905  2912160             20.0
# ...

# %%
subway_df.groupby('day_week').sum()['EXITSn_hourly']
# Out:
# day_week
# 0     9141366.0
# 1    10830056.0
# 2     8978552.0
# 3     8988618.0
# 4     8835194.0
# 5     5695482.0
# 6     5596828.0
# Name: EXITSn_hourly, dtype: float64

# %%
subway_df.groupby('day_week').sum()['ENTRIESn_hourly']
# Out:
# day_week
# 0    12795107.0
# 1    15246943.0
# 2    12592691.0
# 3    12709142.0
# 4    12411679.0
# 5     7486907.0
# 6     7218706.0
# Name: ENTRIESn_hourly, dtype: float64

# %%
subway_df.plot()
